# %%
s = {
  "@id": "ark:59852/schema-cm4ai-image-embedding-labels-prob",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "CM4AI Schema IF Image Labels Probability",
  "description": "Schema for probabilities of a tagged protien appearing in a cellular Component",
  "properties": {
    "gene-symbol": {
      "description": "Gene Symbol for Protein depicted in IF Images",
      "index": 0,
      "valueURL": "http://edamontology.org/data_1026",
      "type": "string",
      "pattern": "^[A-Za-z0-9/-]*$"
    },

    "Nucleoplasm": {
        "description": "",
        "index": 1,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "N. membrane": {
        "description": "",
        "index": 2,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Nucleoli": {
        "description": "",
        "index": 3,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "N. fibrillar c.": {
        "description": "",
        "index": 4,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "N. speckles": {
        "description": "",
        "index": 5,
        "type": "number",
        "minimum": 0,
        "valueURL": None
        },
    "N. bodies": {
        "description": "",
        "index": 6,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "ER": {
        "description": "",
        "index": 7,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Golgi app.": {
        "description": "",
        "index": 8,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Peroxisomes": {
        "description": "",
        "index": 9,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Endosomes": {
        "description": "",
        "index": 10,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Lysosomes": {
        "description": "",
        "index": 11,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Int. fil.": {
        "description": "",
        "index": 12,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Actin fil.": {
        "description": "",
        "index": 13,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "F. a. sites":{
        "description": "",
        "index": 14,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Microtubules":{	
        "description": "",
        "index": 15,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "M. ends": {	
        "description": "",
        "index": 16,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Cyt. bridge": {	
        "description": "",
        "index": 17,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Mitotic spindle": {
        "description": "",
        "index": 18,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "MTOC":{
        "description": "",
        "index": 19,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Centrosome":{	
        "description": "",
        "index": 20,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Lipid droplets": {
        "description": "",
        "index": 21,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "PM": {
        "description": "",
        "index": 22,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "C. Junctions": {
        "description": "",
        "index": 23,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Mitochondria": {
        "description": "",
        "index": 24,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Aggresome": {
        "description": "",
        "index": 25,
        "type": "number",
        "minimum": 0,
        "valueURL": None
      },
    "Cytosol": {
        "description": "",
        "index": 26,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "C. bodies": {
        "description": "",
        "index": 27,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    },
    "Rods & Rings": {
        "description": "",
        "index": 28,
        "type": "number",
        "minimum": 0,
        "valueURL": None
    }
  },
  "type": "object",
  "additionalProperties": False,
  "required": ["gene-symbol"],
  "separator": "\t",
  "header": True,
  "examples": []
}

# %%
null = None
false = False
true = True

# %%
import requests
fairscape_host = "https://fairscape.net/"

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-image-embedding-labels-prob","@type":"evi:Schema","name":"CM4AI Schema IF Image Labels Probability"}}'

# %%
requests.get(fairscape_host + 'schema/ark:59852/schema-cm4ai-image-embedding-labels-prob').content
# Out:
# b'{"@id":"ark:59852/schema-cm4ai-image-embedding-labels-prob","@type":"evi:Schema","@context":{"@vocab":"https://schema.org/","evi":"https://w3id.org/EVI#"},"url":null,"license":" https://creativecommons.org/licenses/by/4.0/","keywords":[],"published":true,"type":"object","additionalProperties":false,"required":["gene-symbol"],"separator":"\\t","header":true,"examples":[],"name":"CM4AI Schema IF Image Labels Probability","description":"Schema for probabilities of a tagged protien appearing in a cellular Component","properties":{"gene-symbol":{"description":"Gene Symbol for Protein depicted in IF Images","index":0,"type":"string","value_url":null,"pattern":"^[A-Za-z0-9/-]*$","items":null,"min_items":null,"max_items":null,"unique_items":null,"valueURL":"http://edamontology.org/data_1026"},"Nucleoplasm":{"description":"","index":1,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"N. membrane":{"description":"","index":2,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Nucleoli":{"description":"","index":3,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"N. fibrillar c.":{"description":"","index":4,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"N. speckles":{"description":"","index":5,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"N. bodies":{"description":"","index":6,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"ER":{"description":"","index":7,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Golgi app.":{"description":"","index":8,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Peroxisomes":{"description":"","index":9,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Endosomes":{"description":"","index":10,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Lysosomes":{"description":"","index":11,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Int. fil.":{"description":"","index":12,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Actin fil.":{"description":"","index":13,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"F. a. sites":{"description":"","index":14,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Microtubules":{"description":"","index":15,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"M. ends":{"description":"","index":16,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Cyt. bridge":{"description":"","index":17,"type":"number","value_url":null,"pattern":null,"items":null,"min_items":null,"max_items":null,"unique_items":null,"minimum":0,"valueURL":null},"Mitotic spindle":{"description":"","index":18,"type" ...

# %%
requests.get(fairscape_host + 'schema').content
# Out:
# b'{"schemas":[]}'

# %%
s2 = {
  "@id": "ark:59852/schema-cm4ai-hierarchy-ppi-cutoff2",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "Hierarchy PPI Cutoff Schema",
  "description": "Schema for the tsv output of the Hierarchy step in the CM4AI pipeline",
  "properties": {
  },
  "type": "object",
  "additionalProperties": False,
  "required": [],
  "separator": "",
  "header": False,
  "examples": []
}


created_schema = requests.post(
    fairscape_host + 'schema',
    json=s2
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-hierarchy-ppi-cutoff2","@type":"evi:Schema","name":"Hierarchy PPI Cutoff Schema"}}'

# %%
s3 = {
  "@id": "ark:59852/schema-cm4ai-apmsloader-gene-node-attributes",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "CM4AI APMS Gene Node Attributes Schema",
  "description": "Schema for APMS embeddings, derived from running node2vec on protien-protien interaction networks obtained from APMS experiments",
  "properties": {
    "name": {
      "description": "Gene Symbol for APMS Data",
      "index": 0,
      "valueURL": "http://edamontology.org/data_1026",
      "type": "string",
      "pattern": "^[A-Za-z0-9/-]*$"
    },
    "represents": {
      "description": "ensembl gene ID for the APMS protien",
      "index": 1,
      "valueURL": "http://edamontology.org/data_1033",
      "type": "string",
      "pattern": "^[A-Z0-9orf/-]*$|^ensembl:(?:ENSG[0-9]{11})(;?ENSG[0-9]{11})*$"
    },
    "bait": {
        "description": "Boolean value indicating if this protien was a bait protien in APMS experiments",
        "type": "boolean",
        "index": 3,
        "valueURL": None
    }
  },
  "type": "object",
  "additionalProperties": False,
  "required": ["name", "represents", "bait"],
  "separator": "\t",
  "header": True,
  "examples": []
}

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s3
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-apmsloader-gene-node-attributes","@type":"evi:Schema","name":"CM4AI APMS Gene Node Attributes Schema"}}'

# %%
s5 = {
  "@id": "ark:59852/schema-cm4ai-imageloader-gene-node-attributes",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "Imageloader Gene Node Attributes",
  "description": "Schema for CM4AI imageloader file image_gene_node_attributes.tsv",
  "properties": {
    "name": {
      "description": "Gene Symbol for the tagged protien",
      "index": 0,
      "valueURL": "http://edamontology.org/data_1026",
      "type": "string",
      "pattern": "^[A-Za-z0-9/-]*$"
    },
    "represents": {
      "description": "Ensembl Gene ID for protien antibody targets, may have multiple matches",
      "index": 1,
      "valueURL": "http://edamontology.org/data_1033",
      "type": "string",
      "pattern": "^(?:ensembl:ENSG[0-9]{11})(;?ensembl:ENSG[0-9]{11})*$|^nan$"
    },
		"ambiguous": {
			"index": 2,
			"type": "boolean",
			"description": "Indicator variable for whether the protien is identified ambiguously"
		},
    "antibody": {
        "description": "Antibody Identifier from Human Protien Atlas or negative control",
        "index": 3,
        "valueURL": "http://edamontology.org/data_2772",
        "type": "string",
        "pattern": "^CAB[0-9]{6}$|^HPA[0-9]{6}$|^NEGATIVE-CTRL$"
    },
    "filename": {
        "description": "The filename of the specified IF image",
        "index": 4,
        "type": "string",
        "pattern": "^B2AI_[0-9]*_.*$"
    },
    "imageurl": {
			"description": "URL for specified uniquely specified IF image",
      "index": 5,
      "type": "string"
    }
  },
  "type": "object",
  "additionalProperties": False,
  "required": ["name", "represents", "ambiguous", "antibody", "filename", "imageurl"],
  "separator": "\t",
  "header": True,
  "examples": []
}

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s5
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-imageloader-gene-node-attributes","@type":"evi:Schema","name":"Imageloader Gene Node Attributes"}}'

# %%
s6 = {
  "@id": "ark:59852/schema-cm4ai-apmsloader-ppi-edgelist",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "APMS PPI Edgelist Schema",
  "description": "Schema for APMS protien-protien interaction networks",
  "properties": {
    "geneA": {
      "description": "Gene Symbol for APMS Bait Protien",
      "index": 0,
      "valueURL": "http://edamontology.org/data_1026",
      "type": "string",
      "pattern": "^[A-Z0-9orf/-]*$"
    },
    "geneB": {
      "description": "Gene Symbol for APMS Prey Protien",
      "index": 1,
      "valueURL": "http://edamontology.org/data_1026",
      "type": "string",
      "pattern": "^[A-Z0-9orf/-]*$|^ensembl:(?:ENSG[0-9]{11})(;?ENSG[0-9]{11})*$"
    }
  },
  "type": "object",
  "additionalProperties": false,
  "required": ["geneA", "geneB"],
  "separator": "\t",
  "header": true,
  "examples": []
}

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s6
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-apmsloader-ppi-edgelist","@type":"evi:Schema","name":"APMS PPI Edgelist Schema"}}'

# %%
s7 = {
  "@id": "ark:59852/schema-cm4ai-imageloader-samplescopy",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "Imageloader Samples Copy Schema",
  "description": "Schema for CM4AI imageloader input file samplescopy.csv",
  "properties": {
    "filename": {
      "description": "Filename for images",
      "index": 0,
      "valueURL": null,
      "type": "string",
      "pattern": null
    },
    "if_plate_id": {
      "description": "Identifies which IF plate the experiment took place on",
      "index": 1,
      "valueURL": null,
      "type": "string",
      "pattern": null
    },
    "position": {
      "description": "The Position of the well for this image in a plate of IF exepriments",
      "index": 2,
      "valueURL": null,
      "type": "string",
      "pattern": "^[A-Z][0-9]*$"
    },
    "sample": {
          "description": "Identifies the sample which was placed in this well",
          "index": 3,
          "valueURL": null,
          "type": "string",
          "pattern": "^[A-Z][0-9]*$"
    },
    "locations": {
          "description": "Cellular Compartments in which the tagged protien was identified through the IF images",
          "index": 4,
          "type": "boolean"
    },
    "antibody": {
        "description": "Antibody Identifier from Human Protien Atlas or negative control",
        "index": 5,
        "valueURL": "http://edamontology.org/data_2772",
        "type": "string",
        "pattern": "^CAB[0-9]{6}$|^HPA[0-9]{6}$|^NEGATIVE-CTRL$"
    },
    "ensembl_ids": {
        "description": "Ensembl Gene ID for protien antibody targets, may have multiple matches",
        "index": "6",
        "valueURL": "http://edamontology.org/data_1033",
        "type": "string",
        "multiple": true,
        "seperator": ";",
        "pattern": "^(?:ENSG[0-9]{11})(;?ENSG[0-9]{11})*$|^nan$"
    },
    "gene_name": {
      "description": "Gene Symbol for the tagged protien",
      "index": 7,
      "valueURL": "http://edamontology.org/data_1026",
      "type": "string",
      "pattern": null 
    }
  },
  "type": "object",
  "additionalProperties": false,
  "required": ["filename", "if_plate_id", "position", "sample", "antibody", "ensembl_ids"],
  "separator": ",",
  "header": true,
  "examples": []
}

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s7
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-imageloader-samplescopy","@type":"evi:Schema","name":"Imageloader Samples Copy Schema"}}'

# %%
s8 = {
  "@id": "ark:59852/schema-cm4ai-coembedding",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "APMS coembedding CM4AI",
  "description": "Schema for APMS coembeddings, merging the embeddings from IF images and APMS protien-protien interaction networks",
  "properties": {
    "gene-symbol": {
      "description": "Gene Symbol for APMS Data",
      "index": 0,
      "valueURL": "http://edamontology.org/data_1026",
      "type": "string",
      "pattern": "^[A-Za-z0-9/-]*$"
    },
    "coembedding": {
      "description": "embedding vector values for genes determined by running node2vec on APMS networks",
      "index": "1::",
      "valueURL": null,
      "type": "array",
      "minItems": 1,
      "uniqueItems": false,
      "items": {
        "type": "number"
      }
    }
  },
  "type": "object",
  "additionalProperties": false,
  "required": ["gene-symbol", "coembedding"],
  "separator": "\t",
  "header": true,
  "examples": []
}

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s8
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-coembedding","@type":"evi:Schema","name":"APMS coembedding CM4AI"}}'

# %%
s9 = {
  "@id": "ark:59852/schema-cm4ai-apms-embedding",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "APMS Embedding CM4AI",
  "description": "Schema for APMS embeddings, derived from running node2vec on protien-protien interaction networks obtained from APMS experiments",
  "properties": {
    "gene-symbol": {
      "description": "Gene Symbol for APMS Data",
      "index": 0,
      "valueURL": "http://edamontology.org/data_1026",
      "type": "string",
      "pattern": "^[A-Za-z0-9/-]*$"
    },
    "embedding": {
      "description": "embedding vector values for genes determined by running node2vec on APMS networks",
      "index": "1::",
      "valueURL": null,
      "type": "array",
      "minItems": 1,
      "uniqueItems": false,
      "items": {
        "type": "number"
      }
    }
  },
  "type": "object",
  "additionalProperties": false,
  "required": ["gene-symbol", "embedding"],
  "separator": "\t",
  "header": true,
  "examples": []
}

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s9
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-apms-embedding","@type":"evi:Schema","name":"APMS Embedding CM4AI"}}'

# %%
s10 = {
  "@id": "ark:59852/schema-cm4ai-hierarchy-cx",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "CM4AI CX network file schema",
  "description": "Schema for the CX heirarchy network output",
  "properties": {
  },
  "type": "object",
  "additionalProperties": false,
  "required": [],
  "separator": "",
  "header": false,
  "examples": []
}

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s10
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-hierarchy-cx","@type":"evi:Schema","name":"CM4AI CX network file schema"}}'

# %%
s11 = {
  "@id": "ark:59852/schema-cm4ai-image-embedding-image-emd",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id.org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "CM4AI Schema IF Image Embeddings",
  "description": "Schema for Image Embeddings",
  "properties": {
    "gene-symbol": {
      "description": "Gene Symbol for IF Image protein tagged",
      "index": 0,
      "valueURL": "http://edamontology.org/data_1026",
      "type": "string",
      "pattern": "^[A-Za-z0-9/-]*$"
    },
    "image-embedding": {
      "description": "embedding vector values generated from IF images",
      "index": "1::",
      "valueURL": null,
      "type": "array",
      "maxItems": 1024,
      "minItems": 1024,
      "uniqueItems": false,
      "items": {
        "type": "number"
      }
    }
  },
  "type": "object",
  "additionalProperties": false,
  "required": ["gene-symbol", "image-embedding"],
  "separator": "\t",
  "header": true,
  "examples": []
}

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s11
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-image-embedding-image-emd","@type":"evi:Schema","name":"CM4AI Schema IF Image Embeddings"}}'

# %%
s12 = {
  "@id": "ark:59852/schema-cm4ai-imageloader-uniquecopy",
  "@context": {
      "@vocab": "https://schema.org/",
      "EVI": "https://w3id,org/EVI#"
    },
  "@type": "EVI:Schema",
  "name": "Imageloader Uniquecopy Schema",
  "description": "Schema for the cm4ai imageloader input file uniquecopy",
  "properties": {
    "antibody": {
        "description": "Antibody Identifier from Human Protien Atlas or negative control",
        "index": 0,
        "valueURL": "http://edamontology.org/data_2772",
        "type": "string",
        "pattern": "^CAB[0-9]{6}$|^HPA[0-9]{6}$|^NEGATIVE-CTRL$"
    },
    "ensembl_ids": {
        "description": "Ensembl Gene ID for protien antibody targets, may have multiple matches",
        "index": "1",
          "valueURL": "http://edamontology.org/data_1033",
          "type": "string",
          "multiple": true,
          "seperator": ";",
          "pattern": "^(?:ENSG[0-9]{11})(;?ENSG[0-9]{11})*$|^nan$"
    },
    "gene_names": {
        "description": "Gene Names for the Protien",
        "index": 2,
        "type": "boolean"
    },
    "atlas_name": {
        "description": "The Cell Line Name on which this IF antibody staining experiment took place",
        "type": "string",
        "index": 3,
        "valueURL": "http://edamontology.org/data_2317"
    },
    "locations": {
        "description": "Locations in the Cell in which the tagged protien was identified",
        "index": 4,
        "type": "boolean"
    },
    "n_location": {
        "description": "Number of Locations in the cell where the taggedprotien was identified",
        "index": 5,
        "type": "integer"
    }
  },
  "type": "object",
  "additionalProperties": false,
  "required": ["antibody", "ensembl_ids", "atlas_name"],
  "separator": ",",
  "header": true,
  "examples": []
}

created_schema = requests.post(
    fairscape_host + 'schema',
    json=s12
    )

print(created_schema.status_code)
print(created_schema.content)
# Out:
# 201
# b'{"created":{"@id":"ark:59852/schema-cm4ai-imageloader-uniquecopy","@type":"evi:Schema","name":"Imageloader Uniquecopy Schema"}}'
